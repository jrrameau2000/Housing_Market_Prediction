# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as px
import plotly
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Median Home Prices

df1= pd.read_csv(Path('c:/users/Tavar/Downloads/US Median Home Price  - Sheet1 (1).csv'))

df1
# Out:
#       Month  Median Home Price Inflation Adjusted Price
# 0     5/1/04       $181,893.38              $254,782.51
# 1     6/1/04       $184,363.48              $257,425.65
# 2     7/1/04       $185,882.06              $259,957.14
# 3     8/1/04       $187,121.91              $261,552.98
# 4     9/1/04       $188,169.54              $262,463.31
# ..       ...               ...                      ...
# 198  11/1/20       $299,006.77              $304,347.38
# 199  12/1/20       $300,929.02              $306,015.86
# 200   1/1/21       $303,331.84              $307,152.74
# 201   2/1/21       $307,849.14              $310,029.72
# 202   3/1/21       $314,769.26              $314,769.26
#
# [203 rows x 3 columns]

# %%
plt.plot()
# Out:
#   File "<ipython-input-26-4c79c619c0b2>", line 1
#     plt.plot(data.Median Home Price)
#                          ^
# SyntaxError: invalid syntax

# %%
df2= pd.read_csv(Path('c:/users/Tavar/Downloads/Number of holmes sold in the US from 2005 to 2021 - Sheet1.csv'))

df2
# Out:
#     Year  # of homes sold in millions
# 0   2005                         7.08
# 1   2006                         6.52
# 2   2007                         5.02
# 3   2008                         4.12
# 4   2009                         4.34
# 5   2010                         4.18
# 6   2011                         4.26
# 7   2012                         4.66
# 8   2013                         5.09
# 9   2014                         4.94
# 10  2015                         5.25
# 11  2016                         5.45
# 12  2017                         5.51
# 13  2018                         5.34
# 14  2019                         5.34
# 15  2020                         5.64
# 16  2021                         6.49

# %%
df2.plot.bar(x='Year')

plt.rcParams['figure.figsize'] = (10,10)
