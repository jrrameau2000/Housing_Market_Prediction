# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as px
import plotly
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Median Home Prices

df1= pd.read_csv(Path('c:/users/Tavar/Downloads/US Median Home Price  - Sheet1 (1).csv'),index_col="Month " , parse_dates = True)

df1= df.replace({"\$":"",",":""},regex=True)
df1.set_index("Month ", inplace=True)

df1=df1.apply(pd.to_numeric)

df1
# Out:
#          Median Home Price  Inflation Adjusted Price
# Month
# 5/1/04           181893.38                 254782.51
# 6/1/04           184363.48                 257425.65
# 7/1/04           185882.06                 259957.14
# 8/1/04           187121.91                 261552.98
# 9/1/04           188169.54                 262463.31
# ...                    ...                       ...
# 11/1/20          299006.77                 304347.38
# 12/1/20          300929.02                 306015.86
# 1/1/21           303331.84                 307152.74
# 2/1/21           307849.14                 310029.72
# 3/1/21           314769.26                 314769.26
#
# [203 rows x 2 columns]

# %%
#Plot the Median Prices with Inflation Adjusted Prices
df1.plot()
# Out:
# <AxesSubplot:xlabel='Month '>

# %%
# Number of homes sold each year from 2005 - 2021. 2021 number of sales is an estimate

df2= pd.read_csv(Path('c:/users/Tavar/Downloads/Number of holmes sold in the US from 2005 to 2021 - Sheet1.csv'))

df2
# Out:
#     Year  # of homes sold in millions
# 0   2005                         7.08
# 1   2006                         6.52
# 2   2007                         5.02
# 3   2008                         4.12
# 4   2009                         4.34
# 5   2010                         4.18
# 6   2011                         4.26
# 7   2012                         4.66
# 8   2013                         5.09
# 9   2014                         4.94
# 10  2015                         5.25
# 11  2016                         5.45
# 12  2017                         5.51
# 13  2018                         5.34
# 14  2019                         5.34
# 15  2020                         5.64
# 16  2021                         6.49

# %%
# Visual of number of homes sold each year

df2.plot.bar(x='Year')

plt.rcParams['figure.figsize'] = (12,12)
